# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data_2019 = pd.read_csv('data/GE_india_2019_results.csv',encoding= 'unicode_escape')
Data_2014 = pd.read_csv('data/GE_india_2014_results.csv',encoding= 'unicode_escape')

# %%
Data_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8568 entries, 0 to 8567
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state/ut        8568 non-null   object
#  1   PC              8568 non-null   object
#  2   candidate_name  8568 non-null   object
#  3   party           8568 non-null   object
#  4   evm_votes       8568 non-null   int64
#  5   postal_votes    8568 non-null   int64
#  6   migrant_votes   85 non-null     float64
#  7   total_votes     8568 non-null   int64
#  8   percent_votes   8568 non-null   float64
#  9   rank            8568 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 669.5+ KB

# %%
Data_2019.head()
# Out:
#                     state/ut                         PC  \
# 0  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#           candidate_name                     party  evm_votes  postal_votes  \
# 0     KULDEEP RAI SHARMA  Indian National Congress      95249            59
# 1           VISHAL JOLLY    Bharatiya Janata Party      93772           129
# 2  PARITOSH KUMAR HALDAR               Independent       5339             2
# 3         SANJAY MESHACK           Aam Aadmi Party       2837             2
# 4           PRAKASH MINJ       Bahujan Samaj Party       2478             8
#
#    migrant_votes  total_votes  percent_votes  rank
# 0            NaN        95308          45.98     1
# 1            NaN        93901          45.30     2
# 2            NaN         5341           2.58     3
# 3            NaN         2839           1.37     4
# 4            NaN         2486           1.20     5

# %%
Data_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8355 entries, 0 to 8354
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   state/ut        8355 non-null   object
#  1   PC              8355 non-null   object
#  2   candidate_name  8355 non-null   object
#  3   party           8355 non-null   object
#  4   evm_votes       8355 non-null   int64
#  5   postal_votes    8355 non-null   int64
#  6   total_votes     8355 non-null   int64
#  7   Rank            8355 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 522.3+ KB

# %%
Data_2014.head()
# Out:
#          state/ut         PC    candidate_name                      party  \
# 0  Andhra Pradesh  Adilabad       GODAM NAGESH  Telangana Rashtra Samithi
# 1  Andhra Pradesh  Adilabad             NARESH   Indian National Congress
# 2  Andhra Pradesh  Adilabad      RAMESH RATHOD               Telugu Desam
# 3  Andhra Pradesh  Adilabad    RATHOD SADASHIV        Bahujan Samaj Party
# 4  Andhra Pradesh  Adilabad   NETHAWATH RAMDAS                Independent
#
#    evm_votes  postal_votes  total_votes  Rank
# 0     425762          5085       430847     1
# 1     257994          1563       259557     2
# 2     182879          1319       184198     3
# 3      94363            57        94420     4
# 4      41028             4        41032     5

# %%
#columns in 2019 not in 2014

set(Data_2014.columns) - set(Data_2019.columns)
# Out:
# {'Rank'}

# %%
#columns in 2014 not in 2019

set(Data_2019.columns) - set(Data_2014.columns)
# Out:
# {'migrant_votes', 'percent_votes', 'rank'}

# %%
Data_2014.rename(columns = {'Rank':'rank'},inplace = True)

# %%
Data_2019 = Data_2019[Data_2014.columns]

# %%
str_col = ['state/ut', 'PC', 'candidate_name', 'party']

for i in str_col:
    Data_2014[i] = Data_2014[i].str.strip().str.upper()
    Data_2019[i] = Data_2019[i].str.strip().str.upper()

# %%
Data_2014['year'] =2014
Data_2019['year'] =2019

election_data = pd.concat([Data_2014,Data_2019],ignore_index = True)
election_data.head()
# Out:
#          state/ut        PC    candidate_name                      party  \
# 0  ANDHRA PRADESH  ADILABAD      GODAM NAGESH  TELANGANA RASHTRA SAMITHI
# 1  ANDHRA PRADESH  ADILABAD            NARESH   INDIAN NATIONAL CONGRESS
# 2  ANDHRA PRADESH  ADILABAD     RAMESH RATHOD               TELUGU DESAM
# 3  ANDHRA PRADESH  ADILABAD   RATHOD SADASHIV        BAHUJAN SAMAJ PARTY
# 4  ANDHRA PRADESH  ADILABAD  NETHAWATH RAMDAS                INDEPENDENT
#
#    evm_votes  postal_votes  total_votes  rank  year
# 0     425762          5085       430847     1  2014
# 1     257994          1563       259557     2  2014
# 2     182879          1319       184198     3  2014
# 3      94363            57        94420     4  2014
# 4      41028             4        41032     5  2014

# %%
election_data.hist(figsize = [25,25])
plt.show()

# %%
g = sns.pairplot(election_data
                 ,hue = 'year'
                 ,corner=True
                 ,plot_kws = {'alpha': 0.4, 's': 80, 'edgecolor': 'k'}
                 ,palette = 'cool')

# %% [markdown]
# ### Was there any increase in number of constituency in any state?

# %%
tst_df = election_data[['state/ut','PC','year']].drop_duplicates().groupby(['state/ut','year']).count().reset_index()
plt.figure(figsize = [25,10])
plt.title('Count of PC per state in 2014 and 2019')
ax = sns.barplot(x='state/ut', y='PC', hue = 'year', data=tst_df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Number of constituency, has not changed, but Andhra Pradesh it has reduced, this could be because of formation of Telangana State. Apart from that there was no change in number or constituency.

# %% [markdown]
# ### Percent increase of voters wrt last term.

# %%
df = election_data.pivot_table(index='state/ut',columns=['year'],values = 'total_votes', aggfunc = 'sum').dropna().reset_index()
df.columns = ['state/ut','2014','2019']
df['Pct chg in voters'] = (df['2019']-df['2014'])/df['2014']*100
df.sort_values(by = ['Pct chg in voters'],inplace = True)

plt.figure(figsize = [25,10])
plt.title('Percent change in voters')
ax = sns.barplot(x='state/ut', y='Pct chg in voters', data=df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# AP has reduced number of voters, because of new state formation.
#
# Meghalay has highest increase in voter turn over. Similarly in North Eastern states in Mizoram and Assam.

# %% [markdown]
# ### Voters share per State

# %%
import squarify

df = election_data.groupby(['year','state/ut'])['total_votes'].sum().reset_index()
for i in [2014,2019]:
    x = sum(df[df['year'] == i]['total_votes'])
    df.loc[df['year'] == i,'Pct Voters'] = (df[df['year'] == i]['total_votes']/x)*100
    plt.figure(figsize = [25,25])
    plt.title(str('Voters share per State '+str(i)))
    df.sort_values(by = ['year','Pct Voters'],inplace = True)
    squarify.plot(sizes=df[df['year'] == i]['total_votes'],label=df[df['year'] == i]['state/ut'], alpha=.8 )
    plt.show()

# %% [markdown]
# UP has the highest voters.
#
# Maharshtra and WB have similar number of voters.

# %% [markdown]
# ### Comparision of candidates per year.

# %%
tst_df = election_data[['state/ut','candidate_name','year']].drop_duplicates().groupby(['state/ut','year']).count().reset_index()
plt.figure(figsize = [25,10])
plt.title('Count of candidates per state in 2014 and 2019')
ax = sns.barplot(x='state/ut', y='candidate_name', hue = 'year', data=tst_df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Typically number of candidates should stay same or increase. But that doesn't seem to be case is UP, weirdly number of candidates have decreased.

# %% [markdown]
# ### Dominant Parties in each state

# %%
df = election_data[election_data['rank']==1].groupby(['state/ut','party','year'])['PC'].count().reset_index()
df
# Out:
#                       state/ut                                party  year  PC
# 0    ANDAMAN & NICOBAR ISLANDS             INDIAN NATIONAL CONGRESS  2019   1
# 1    ANDAMAN & NICOBAR ISLANDS           NATIONALIST CONGRESS PARTY  2014   1
# 2               ANDHRA PRADESH                  BAHUJAN SAMAJ PARTY  2014  11
# 3               ANDHRA PRADESH               BHARATIYA JANATA PARTY  2014   3
# 4               ANDHRA PRADESH             COMMUNIST PARTY OF INDIA  2014   1
# ..                         ...                                  ...   ...  ..
# 202                WEST BENGAL               BHARATIYA JANATA PARTY  2014   4
# 203                WEST BENGAL               BHARATIYA JANATA PARTY  2019  18
# 204                WEST BENGAL  COMMUNIST PARTY OF INDIA  (MARXIST)  2014   7
# 205                WEST BENGAL             INDIAN NATIONAL CONGRESS  2014  16
# 206                WEST BENGAL             INDIAN NATIONAL CONGRESS  2019   2
#
# [207 rows x 4 columns]

# %%
df = df.groupby(['state/ut', 'year']).agg({'PC':'max','party':'max'}).reset_index()
df
# Out:
#                      state/ut  year  PC                                  party
# 0   ANDAMAN & NICOBAR ISLANDS  2014   1             NATIONALIST CONGRESS PARTY
# 1   ANDAMAN & NICOBAR ISLANDS  2019   1               INDIAN NATIONAL CONGRESS
# 2              ANDHRA PRADESH  2014  15                           TELUGU DESAM
# 3              ANDHRA PRADESH  2019  22  YUVAJANA SRAMIKA RYTHU CONGRESS PARTY
# 4           ARUNACHAL PRADESH  2014   1             NATIONALIST CONGRESS PARTY
# ..                        ...   ...  ..                                    ...
# 64              UTTAR PRADESH  2019  62                        SAMAJWADI PARTY
# 65                UTTARAKHAND  2014   3                 BHARATIYA JANATA PARTY
# 66                UTTARAKHAND  2019   5                 BHARATIYA JANATA PARTY
# 67                WEST BENGAL  2014  16               INDIAN NATIONAL CONGRESS
# 68                WEST BENGAL  2019  22               INDIAN NATIONAL CONGRESS
#
# [69 rows x 4 columns]

# %% [markdown]
# ### Parties whose dominance prevailes

# %%
df = df.pivot(index='state/ut',columns=['year'],values = 'party').dropna().reset_index()
df
# Out:
# year                   state/ut                                         2014  \
# 0     ANDAMAN & NICOBAR ISLANDS                   NATIONALIST CONGRESS PARTY
# 1                ANDHRA PRADESH                                 TELUGU DESAM
# 2             ARUNACHAL PRADESH                   NATIONALIST CONGRESS PARTY
# 3                         ASSAM                     INDIAN NATIONAL CONGRESS
# 4                         BIHAR                         RASHTRIYA JANATA DAL
# 5                    CHANDIGARH                       BHARATIYA JANATA PARTY
# 6          DADRA & NAGAR HAVELI                   NATIONALIST CONGRESS PARTY
# 7                   DAMAN & DIU                     INDIAN NATIONAL CONGRESS
# 8                           GOA                     INDIAN NATIONAL CONGRESS
# 9                       GUJARAT                   NATIONALIST CONGRESS PARTY
# 10                      HARYANA                     INDIAN NATIONAL CONGRESS
# 11             HIMACHAL PRADESH                     INDIAN NATIONAL CONGRESS
# 12              JAMMU & KASHMIR     JAMMU & KASHMIR PEOPLES DEMOCRATIC PARTY
# 13                    JHARKHAND                                          JVM
# 14                    KARNATAKA                         JANATA DAL (SECULAR)
# 15                       KERALA                          KERALA CONGRESS (M)
# 16                  LAKSHADWEEP          COMMUNIST PARTY OF INDIA  (MARXIST)
# 17               MADHYA PRADESH                     INDIAN NATIONAL CONGRESS
# 18                  MAHARASHTRA                                     SHIVSENA
# 19                      MANIPUR                     INDIAN NATIONAL CONGRESS
# 20                    MEGHALAYA                      UNITED DEMOCRATIC PARTY
# 21                      MIZORAM                     INDIAN NATIONAL CONGRESS
# 22                     NAGALAND                       NAGALAND PEOPLES FRONT
# 23                 NCT OF DELHI                     INDIAN NATIONAL CONGRESS
# 24                   PUDUCHERRY                        PATTALI MAKKAL KATCHI
# 25                       PUNJAB                          SHIROMANI AKALI DAL
# 26                    RAJASTHAN                     INDIAN NATIONAL CONGRESS
# 27                       SIKKIM                     INDIAN NATIONAL CONGRESS
# 28                   TAMIL NADU  SOCIALIST UNITY CENTRE OF INDIA (COMMUNIST)
# 29                      TRIPURA                     INDIAN NATIONAL CONGRESS
# 30                UTTAR PRADESH                              SAMAJWADI PARTY
# 31                  UTTARAKHAND                       BHARATIYA JANATA PARTY
# 32                  WEST BENGAL                     INDIAN NATIONAL CONGRESS
#
# year                                      2019
# 0                     INDIAN NATIONAL CONGRESS
# 1        YUVAJANA SRAMIKA RYTHU CONGRESS PARTY
# 2                       BHARATIYA JANATA PARTY
# 3                     INDIAN NATIONAL CONGRESS
# 4                         LOK JAN SHAKTI PARTY
# 5                       BHARATIYA JANATA PARTY
# 6                                  INDEPENDENT
# 7                       BHARATIYA JANATA PARTY
# 8                     INDIAN NATIONAL CONGRESS
# 9                       BHARATIYA JANATA PARTY
# 10                      BHARATIYA JANATA PARTY
# 11                      BHARATIYA JANATA PARTY
# 12         JAMMU & KASHMIR NATIONAL CONFERENCE
# 13                      JHARKHAND MUKTI MORCHA
# 14                       JANATA DAL  (SECULAR)
# 15               REVOLUTIONARY SOCIALIST PARTY
# 16                  NATIONALIST CONGRESS PARTY
# 17                    INDIAN NATIONAL CONGRESS
# 18                                    SHIVSENA
# 19                          NAGA PEOPLES FRONT
# 20                     NATIONAL PEOPLE'S PARTY
# 21                         MIZO NATIONAL FRONT
# 22    NATIONALIST DEMOCRATIC PROGRESSIVE PARTY
# 23                      BHARATIYA JANATA PARTY
# 24                    INDIAN NATIONAL CONGRESS
# 25                         SHIROMANI AKALI DAL
# 26                  RASHTRIYA LOKTANTRIK PARTY
# 27                    SIKKIM KRANTIKARI MORCHA
# 28              VIDUTHALAI CHIRUTHAIGAL KATCHI
# 29                      BHARATIYA JANATA PARTY
# 30                             SAMAJWADI PARTY
# 31                      BHARATIYA JANATA PARTY
# 32                    INDIAN NATIONAL CONGRESS

# %%
df.columns
# Out:
# Index(['state/ut', 2014, 2019], dtype='object', name='year')

# %%
df['Match'] = df[2014] == df[2019]
df[df['Match']]
# Out:
# year        state/ut                      2014                      2019  \
# 3              ASSAM  INDIAN NATIONAL CONGRESS  INDIAN NATIONAL CONGRESS
# 5         CHANDIGARH    BHARATIYA JANATA PARTY    BHARATIYA JANATA PARTY
# 8                GOA  INDIAN NATIONAL CONGRESS  INDIAN NATIONAL CONGRESS
# 17    MADHYA PRADESH  INDIAN NATIONAL CONGRESS  INDIAN NATIONAL CONGRESS
# 18       MAHARASHTRA                  SHIVSENA                  SHIVSENA
# 25            PUNJAB       SHIROMANI AKALI DAL       SHIROMANI AKALI DAL
# 30     UTTAR PRADESH           SAMAJWADI PARTY           SAMAJWADI PARTY
# 31       UTTARAKHAND    BHARATIYA JANATA PARTY    BHARATIYA JANATA PARTY
# 32       WEST BENGAL  INDIAN NATIONAL CONGRESS  INDIAN NATIONAL CONGRESS
#
# year  Match
# 3      True
# 5      True
# 8      True
# 17     True
# 18     True
# 25     True
# 30     True
# 31     True
# 32     True

# %% [markdown]
# ### Candidates that repeated in states and district

# %%
df = election_data[election_data['rank']==1][['state/ut','PC','candidate_name','year']].pivot(index = ['state/ut','PC']
                                                                              ,columns = 'year'
                                                                              ,values = 'candidate_name').fillna('NOT AVAILABLE').reset_index()
df.columns = ['state/ut','PC','2014','2019']
df.head()

df['Match'] = df['2014'] == df['2019']
df[df['Match']].groupby(['state/ut'])['Match'].count()
# Out:
# state/ut
# ANDHRA PRADESH      1
# BIHAR               1
# CHANDIGARH          1
# GUJARAT             2
# HIMACHAL PRADESH    1
# JHARKHAND           1
# KARNATAKA           3
# KERALA              1
# MADHYA PRADESH      2
# MAHARASHTRA         2
# PUNJAB              2
# RAJASTHAN           1
# TAMIL NADU          3
# UTTAR PRADESH       6
# UTTARAKHAND         2
# WEST BENGAL         7
# Name: Match, dtype: int64

# %%
df[df['Match']]
# Out:
#              state/ut                 PC                             2014  \
# 29     ANDHRA PRADESH            NELLORE           ADALA PRABHAKARA REDDY
# 65              BIHAR              BUXAR            ASHWINI KUMAR CHOUBEY
# 99         CHANDIGARH         CHANDIGARH                      KIRRON KHER
# 118           GUJARAT             AMRELI  KACHHADIYA NARANBHAI BHIKHABHAI
# 128           GUJARAT           JUNAGADH   CHUDASAMA RAJESHBHAI NARANBHAI
# 152  HIMACHAL PRADESH           HAMIRPUR              ANURAG SINGH THAKUR
# 166         JHARKHAND              GODDA                  NISHIKANT DUBEY
# 181         KARNATAKA            BELGAUM      ANGADI SURESH CHANNABASAPPA
# 196         KARNATAKA             KOPPAL         KARADI SANGANNA AMARAPPA
# 203         KARNATAKA     UTTARA KANNADA                 ANANTKUMAR HEGDE
# 218            KERALA     PATHANAMTHITTA                      ANTO ANTONY
# 235    MADHYA PRADESH        HOSHANGABAD                UDAY PRATAP SINGH
# 246    MADHYA PRADESH               REWA                  JANARDAN MISHRA
# 267       MAHARASHTRA  GADCHIROLI-CHIMUR            ASHOK MAHADEORAO NETE
# 286       MAHARASHTRA             NASHIK             GODSE HEMANT TUKARAM
# 341            PUNJAB           BATHINDA             HARSIMRAT KAUR BADAL
# 347            PUNJAB          JALANDHAR          SANTOKH SINGH CHAUDHARY
# 377         RAJASTHAN            UDAIPUR                   ARJUNLAL MEENA
# 399        TAMIL NADU           NILGIRIS                         RAJA, A.
# 404        TAMIL NADU          SIVAGANGA              KARTI P CHIDAMBARAM
# 414        TAMIL NADU     TIRUVANNAMALAI                    ANNADURAI C N
# 451     UTTAR PRADESH           BANSGAON                   KAMLESH PASWAN
# 461     UTTAR PRADESH       DOMARIYAGANJ                   JAGDAMBIKA PAL
# 475     UTTAR PRADESH           HAMIRPUR  KUNWAR PUSHPENDRA SINGH CHANDEL
# 492     UTTAR PRADESH           MAINPURI              MULAYAM SINGH YADAV
# 497     UTTAR PRADESH       MOHANLALGANJ                  KAUSHAL KISHORE
# 500     UTTAR PRADESH             NAGINA                   GIRISH CHANDRA
# 517       UTTARAKHAND             ALMORA                       AJAY TAMTA
# 521       UTTARAKHAND      TEHRI GARHWAL            MALA RAJYA LAXMI SHAH
# 523       WEST BENGAL           ARAMBAGH       APARUPA PODDAR (AFRIN ALI)
# 525       WEST BENGAL         BAHARAMPUR           ADHIR RANJAN CHOWDHURY
# 535       WEST BENGAL          BISHNUPUR                    KHAN SAUMITRA
# 542       WEST BENGAL             GHATAL            ADHIKARI DEEPAK (DEV)
# 551       WEST BENGAL    KOLKATA DAKSHIN                         MALA ROY
# 555       WEST BENGAL      MALDAHA UTTAR                     KHAGEN MURMU
# 556       WEST BENGAL         MATHURAPUR            CHOUDHURY MOHAN JATUA
#
#                                 2019  Match
# 29            ADALA PRABHAKARA REDDY   True
# 65             ASHWINI KUMAR CHOUBEY   True
# 99                       KIRRON KHER   True
# 118  KACHHADIYA NARANBHAI BHIKHABHAI   True
# 128   CHUDASAMA RAJESHBHAI NARANBHAI   True
# 152              ANURAG SINGH THAKUR   True
# 166                  NISHIKANT DUBEY   True
# 181      ANGADI SURESH CHANNABASAPPA   True
# 196         KARADI SANGANNA AMARAPPA   True
# 203                 ANANTKUMAR HEGDE   True
# 218                      ANTO ANTONY   True
# 235                UDAY PRATAP SINGH   True
# 246                  JANARDAN MISHRA   True
# 267            ASHOK MAHADEORAO NETE   True
# 286             GODSE HEMANT TUKARAM   True
# 341             HARSIMRAT KAUR BADAL   True
# 347          SANTOKH SINGH CHAUDHARY   True
# 377                   ARJUNLAL MEENA   True
# 399                         RAJA, A.   True
# 404              KARTI P CHIDAMBARAM   True
# 414                    ANNADURAI C N   True
# 451                   KAMLESH PASWAN   True
# 461                   JAGDAMBIKA PAL   True
# 475  KUNWAR PUSHPENDRA SINGH CHANDEL   True
# 492              MULAYAM SINGH YADAV   True
# 497                  KAUSHAL KISHORE   True
# 500                   GIRISH CHANDRA   True
# 517                       AJAY TAMTA   True
# 521            MALA RAJYA LAXMI SHAH   True
# 523       APARUPA PODDAR (AFRIN ALI)   True
# 525           ADHIR RANJAN CHOWDHURY   True
# 535                    KHAN SAUMITRA   True
# 542            ADHIKARI DEEPAK (DEV)   True
# 551                         MALA ROY   True
# 555                     KHAGEN MURMU   True
# 556            CHOUDHURY MOHAN JATUA   True

# %% [markdown]
# ### Voters per constituency for each State

# %%
df = (election_data.groupby(by = ['state/ut','year'])['total_votes'].sum() / election_data.groupby(by = ['state/ut','year'])['PC'].count()).reset_index()

# %%
df.rename(columns = {0:'Voters Density'},inplace = True)

# %%
plt.figure(figsize = [25,10])
plt.title('Count of candidates per state in 2014 and 2019')
ax = sns.barplot(x='state/ut', y='Voters Density', hue = 'year', data=df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Total_votes cann't be a great indicator to understand voters turnout. Voters density will explain the averge vote per constituency. This will explain on an average no. of votes per constituency.
# A lower density might be a red flag. A higher density could mean a place for creating new constituency.

# %%
df = df.pivot(index='state/ut',columns=['year'],values = 'Voters Density').dropna().reset_index()

# %%
df['Pct chg in voters density'] = (df[2019]-df[2014])/df[2014]*100
df.sort_values(by = ['Pct chg in voters density'],inplace = True)

plt.figure(figsize = [25,10])
plt.title('Percent change in voters density')
ax = sns.barplot(x='state/ut', y='Pct chg in voters density', data=df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# An higher number should be a positive indicator, that voter turnout has improved. Eg.'Puducherry' and 'Goa' seems to have higher voter turnout.
